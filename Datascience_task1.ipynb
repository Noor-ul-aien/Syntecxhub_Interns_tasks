# %%
#Project 1
import pandas as pd
#used titanic dataset
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# 1. Convert DataFrame to NumPy Array

# %%
data= df.to_numpy()
data.shape
# Out:
# (891, 12)

# %% [markdown]
# 2. Array Creation, Indexing & Slicing

# %%
print("row 1:",data[0])
print("row form 1 to 5",data[0:5])
# Out:
# row 1: [1 0 3 'Braund, Mr. Owen Harris' 'male' 22.0 1 0 'A/5 21171' 7.25 nan 'S']
# row form 1 to 5 [[1 0 3 'Braund, Mr. Owen Harris' 'male' 22.0 1 0 'A/5 21171' 7.25 nan
#   'S']
#  [2 1 1 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)' 'female'
#   38.0 1 0 'PC 17599' 71.2833 'C85' 'C']
#  [3 1 3 'Heikkinen, Miss. Laina' 'female' 26.0 0 0 'STON/O2. 3101282'
#   7.925 nan 'S']
#  [4 1 1 'Futrelle, Mrs. Jacques Heath (Lily May Peel)' 'female' 35.0 1 0
#   '113803' 53.1 'C123' 'S']
#  [5 0 3 'Allen, Mr. William Henry' 'male' 35.0 0 0 '373450' 8.05 nan 'S']]

# %%
print("from row 1 column 4 returns simple value no array= ",data[0,4])
# Out:
# from row 1 column 4 returns simple value no array=  male

# %%
print("from row 1 column 4 returns  array= ",data[0:1,4])
# Out:
# from row 1 column 4 returns  array=  ['male']

# %%
print("gender column:", data[:, 4])
# Out:
# First column: ['male' 'female' 'female' 'female' 'male' 'male' 'male' 'male' 'female'
#  'female' 'female' 'female' 'male' 'male' 'female' 'female' 'male' 'male'
#  'female' 'female' 'male' 'male' 'female' 'male' 'female' 'female' 'male'
#  'male' 'female' 'male' 'male' 'female' 'female' 'male' 'male' 'male'
#  'male' 'male' 'female' 'female' 'female' 'female' 'male' 'female'
#  'female' 'male' 'male' 'female' 'male' 'female' 'male' 'male' 'female'
#  'female' 'male' 'male' 'female' 'male' 'female' 'male' 'male' 'female'
#  'male' 'male' 'male' 'male' 'female' 'male' 'female' 'male' 'male'
#  'female' 'male' 'male' 'male' 'male' 'male' 'male' 'male' 'female' 'male'
#  'male' 'female' 'male' 'female' 'female' 'male' 'male' 'female' 'male'
#  'male' 'male' 'male' 'male' 'male' 'male' 'male' 'male' 'female' 'male'
#  'female' 'male' 'male' 'male' 'male' 'male' 'female' 'male' 'male'
#  'female' 'male' 'female' 'male' 'female' 'female' 'male' 'male' 'male'
# ...

# %%
print("Passenger names column:", data[:, 3])
# Out:
# Passenger names column: ['Braund, Mr. Owen Harris'
#  'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
#  'Heikkinen, Miss. Laina' 'Futrelle, Mrs. Jacques Heath (Lily May Peel)'
#  'Allen, Mr. William Henry' 'Moran, Mr. James' 'McCarthy, Mr. Timothy J'
#  'Palsson, Master. Gosta Leonard'
#  'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)'
#  'Nasser, Mrs. Nicholas (Adele Achem)' 'Sandstrom, Miss. Marguerite Rut'
#  'Bonnell, Miss. Elizabeth' 'Saundercock, Mr. William Henry'
#  'Andersson, Mr. Anders Johan' 'Vestrom, Miss. Hulda Amanda Adolfina'
#  'Hewlett, Mrs. (Mary D Kingcome) ' 'Rice, Master. Eugene'
#  'Williams, Mr. Charles Eugene'
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)'
#  'Masselmani, Mrs. Fatima' 'Fynney, Mr. Joseph J' 'Beesley, Mr. Lawrence'
#  'McGowan, Miss. Anna "Annie"' 'Sloper, Mr. William Thompson'
#  'Palsson, Miss. Torborg Danira'
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)'
# ...

# %% [markdown]
# 3. Mathematical + Axis-wise Operations

# %%
age = df["Age"].to_numpy()
fare = df["Fare"].to_numpy()

print("Age array:", age[:10])
print("Fare array:", fare[:10])
# Out:
# Age array: [22. 38. 26. 35. 35. nan 54.  2. 27. 14.]
# Fare array: [ 7.25   71.2833  7.925  53.1     8.05    8.4583 51.8625 21.075  11.1333
#  30.0708]

# %% [markdown]
# 4. Statistical Operations

# %%
print("Mean Age:", np.nanmean(age))
print("Median Age:", np.nanmedian(age))
print("Min Age:", np.nanmin(age))
print("Max Age:", np.nanmax(age))

print("Mean Fare:", np.nanmean(fare))
print("Median Fare:", np.nanmedian(fare))
print("Min Fare:", np.nanmin(fare))
print("Max Fare:", np.nanmax(fare))
# Out:
# Mean Age: 29.69911764705882
# Median Age: 28.0
# Min Age: 0.42
# Max Age: 80.0
# Mean Fare: 32.204207968574636
# Median Fare: 14.4542
# Min Fare: 0.0
# Max Fare: 512.3292

# %% [markdown]
# 5. Reshaping and Broadcasting

# %%
fare_reshaped = fare.reshape(-1, 1)
print("Reshaped Fare shape:", fare_reshaped.shape)
# Out:
# Reshaped Fare shape: (891, 1)

# %%
fare_plus_10 = fare + 10
print("First 10 fares after adding 10:", fare_plus_10[:10])
# Out:
# First 10 fares after adding 10: [17.25   81.2833 17.925  63.1    18.05   18.4583 61.8625 31.075  21.1333
#  40.0708]

# %% [markdown]
# 6. Save and Load NumPy Arrays

# %%
np.save("fare_data.npy", fare)
loaded_fare = np.load("fare_data.npy")

print("Loaded Fare Array:", loaded_fare[:10])
# Out:
# Loaded Fare Array: [ 7.25   71.2833  7.925  53.1     8.05    8.4583 51.8625 21.075  11.1333
#  30.0708]

# %% [markdown]
# 7. NumPy vs Python List Performance

# %%
import time

python_list = list(range(1000000))
numpy_array = np.arange(1000000)

# Python list performance
start = time.time()
python_result = [x * 2 for x in python_list]
end = time.time()
print("Python list time:", end - start)

# NumPy performance
start = time.time()
numpy_result = numpy_array * 2
end = time.time()
print("NumPy array time:", end - start)
# Out:
# Python list time: 0.07201004028320312
# NumPy array time: 0.0029931068420410156
